# %% [markdown]
# # APIs con Flask
#
# Hemmos utilizado la API de Twitter para obtener el contenido de los tweets de un determinado tema o de una determinada posición. Ahora vamos a ir un paso adelante creano nosotros nuestra propia API.
#
# Existen muchas herramientas y opciones para crear (http://python-eve.org/) pero para seguir trabajando con las herramientas aprendidas nos hemos decantado por trabajar con [flask_restful](http://flask-restful.readthedocs.org/en/latest/index.html)
#
# Para instalarlo
# ```
# pip install flask-restful
# ```

# %% [markdown]
# **COMENTARIOS SOBRE PIP**
# Algunos habéis tenido problemas con las librerías sin saber que versión tenéis o como reinstalar las librerías, aquí os dejo algunas opciones que os pueden ayudar algo:
#
# > pip show nombre-paquete **Mostrará la verión de esta librería **
# >
# > pip search palabra_relacionada_con_el_paquete ** Busca un paquete determinado **
# >
# > sudo pip freeze ** Paquetes instalados de manera global **
# >
# > sudo pip uninstall nombre-paquete ** Desinstala un paquete **
# >
# > sudo pip install --upgrade nombre-paquete ** Actualiza un paquete **
# >
# > sudo pip list --outdated ** Ver que paquetes está cadúcos **

# %% [markdown]
# ## Características de REST
# > ** Client-Server**: There must be a clear separation between the clients and the server.
# >
# > ** Stateless** A client request must contain all the information that is necessary to carry it out. The server must not store any state about the client that persists from one request to the next.
# >
# > ** Cache ** Responses from the server can be labeled as cacheable or noncacheable so that clients (or intermediaries between clients and servers) can use a cache for optimization purposes.
# >
# > ** Uniform Interface ** The protocol by which clients access server resources must be consistent, well defined, and standardized. The commonly used uniform interface of REST web services is the HTTP protocol.
# >
# > **Layered System** Proxy servers, caches, or gateways can be inserted between clients and servers as necessary to improve performance, reliability, and scalability.
# >
# > **Code-on-Demand** Clients can optionally download code from the server to execute in their context.
#
#
#
#
# ## Métodos
# The client application sends requests to the server at the established resource URLs and uses the request method to indicate the desired operation
#
# | HTTP Method        | Action           | Examples |
# | ------------- |:---------------------:| -----:|
# | GET           | Obtain information about a resource |	http://example.com/api/orders (retrieve order list) |
# | GET	        | Obtain information about a resource |		http://example.com/api/orders/123 (retrieve order #123) |
# | POST	        | Create a new resource | http://example.com/api/orders (create a new order, from data provided with the request) |
# | PUT	        | Update a resource     | http://example.com/api/orders/123  (update order #123, from data provided with the request) |
# | DELETE	    | Delete a resource     | http://example.com/api/orders/123 (delete order #123) |
#
# ## Códigos de mensajes HTML
# > Información sobre los [códigos HTML](http://www.w3.org/Protocols/rfc2616/rfc2616-sec10.html)

# %% [markdown]
# ## Realizar pruebas
# Podemos realizar las pruebas de nuestra API con curl para lo que es interesante saber algunas de sus opciones
#
# | -X  |	specify HTTP request method e.g. POST |
# | ------------- |:---------------------|
# | -H  |	 	specify request headers e.g. "Content-type: application/json" |
# | -d  |	 	specify request data e.g. '{"message":"Hello Data"}' |
# | --data-binary  |	 	specify binary request data e.g. @file.bin |
# | -i  |	 	shows the response headers |
# | -u  |	 	specify username and password e.g. "admin:secret" |
# | -v  |	 	enables verbose mode which outputs info such as request and response headers and errors |
#
# >
# > O con httpie, para instalar este último necesitaremos primer instalarlo
#
#
# ```
# sudo apt-get install httpie
# ```

# %% [markdown]
# ## Trabando con Flask
# ### Ejemplo 01
# En principio con Flask tenemos suficiente para poder establecer nuestra API, pues lo único que tenemos que indicar es que ahora lo que devolvemos son datos en formato JSON.

# %%
from flask import Flask, jsonify
abort

app = Flask(__name__)

tasks = [
    {
        'id': 1,
        'title': u'Buy groceries',
        'description': u'Milk, Cheese, Pizza, Fruit, Tylenol', 
        'done': False
    },
    {
        'id': 2,
        'title': u'Learn Python',
        'description': u'Need to find a good Python tutorial on the web', 
        'done': False
    }
]

@app.route('/tasks', methods=['GET'])
def get_tasks():
    return jsonify({'tasks': tasks})

if __name__ == '__main__':
    app.run(debug=True)

# %% [markdown]
# Para poder ver esta información podemos abrir el navegador y usar la dirección del servidor http://127.0.0.1:5000/tasks podemos usar **curl**
#
# ```
# $curl http://127.0.0.1:5000/tasks
# ```
#
# También podemos utilizar la opción **-i** para obtener información de la cabecera
# ```
# $curl -i http://127.0.0.1:5000/tasks
# ```

# %% [markdown]
# ### Ejemplo 02
# En este ejemplo trabajamos con una determinada tarea, y si no se encuentra devolvemos un mensaje de error.

# %%
from flask import Flask, jsonify
# Ahora importamos abort para especificar cuando se ha producido un error
from flask import abort

app = Flask(__name__)

tasks = [
    {
        'id': 1,
        'title': u'Buy groceries',
        'description': u'Milk, Cheese, Pizza, Fruit, Tylenol', 
        'done': False
    },
    {
        'id': 2,
        'title': u'Learn Python',
        'description': u'Need to find a good Python tutorial on the web', 
        'done': False
    }
]

@app.route('/tasks', methods=['GET'])
def get_tasks():
    return jsonify({'tasks': tasks})

@app.route('/tasks/<int:task_id>', methods=['GET'])
def get_task(task_id):
    task = [task for task in tasks if task['id'] == task_id]
    if len(task) == 0:
        abort(404)
    return jsonify({'task': task[0]})


if __name__ == '__main__':
    app.run(debug=True)

# %% [markdown]
# **Problema** En este caso hemos devuelto un error en formato HTML, por lo que deberemos modificar nuestro código para capturar el error 404 y devolver un JSON indicando de dicho error.

# %%
from flask import Flask, jsonify
# Ahora importamos abort para especificar cuando se ha producido un error
from flask import abort
# Importamos make_response para devolver el objeto de error
from flask import make_response

app = Flask(__name__)

tasks = [
    {
        'id': 1,
        'title': u'Buy groceries',
        'description': u'Milk, Cheese, Pizza, Fruit, Tylenol', 
        'done': False
    },
    {
        'id': 2,
        'title': u'Learn Python',
        'description': u'Need to find a good Python tutorial on the web', 
        'done': False
    }
]

@app.route('/tasks', methods=['GET'])
def get_tasks():
    return jsonify({'tasks': tasks})

@app.route('/tasks/<int:task_id>', methods=['GET'])
def get_task(task_id):
    task = [task for task in tasks if task['id'] == task_id]
    if len(task) == 0:
        abort(404)
    return jsonify({'task': task[0]})


@app.errorhandler(404)
def not_found(error):
    return make_response(jsonify({'error': 'Not found'}), 404)


if __name__ == '__main__':
    app.run(debug=True)

# %% [markdown]
# ### Ejemplo 03
# Ahora vamos a implementar la opción de añadir elementos

# %%
# -*- coding: utf-8 -*-
from flask import Flask, jsonify
# Ahora importamos abort para especificar cuando se ha producido un error
from flask import abort
from flask import make_response
# Ahora vamos a implementar añadir elementos, por lo que necesitamos 
# response, algo que ya vimos con la introducción de datos
# desde un formulario
from flask import request

app = Flask(__name__)

tasks = [
    {
        'id': 1,
        'title': u'Buy groceries',
        'description': u'Milk, Cheese, Pizza, Fruit, Tylenol', 
        'done': False
    },
    {
        'id': 2,
        'title': u'Learn Python',
        'description': u'Need to find a good Python tutorial on the web', 
        'done': False
    }
]

@app.route('/tasks', methods=['GET'])
def get_tasks():
    return jsonify({'tasks': tasks})

@app.route('/tasks/<int:task_id>', methods=['GET'])
def get_task(task_id):
    task = [task for task in tasks if task['id'] == task_id]
    if len(task) == 0:
        abort(404)
    return jsonify({'task': task[0]})

@app.errorhandler(404)
def not_found(error):
    return make_response(jsonify({'error': 'Not found'}), 404)

@app.route('/tasks', methods=['POST'])
def create_task():
    if not request.json or not 'title' in request.json:
        abort(400)
    task = {
        'id': tasks[-1]['id'] + 1,
        'title': request.json['title'],
        'description': request.json.get('description', ""),
        'done': False
    }
    tasks.append(task)
    return jsonify({'task': task}), 201


if __name__ == '__main__':
    app.run(debug=True)

# %% [markdown]
# Veamos ahora el resultado. En este caso le añado una descripción
# ```
# curl -i -H "Content-Type: application/json" -X POST -d '{"title":"Comer", "description":"general"}' http://localhost:5000/tasks
# ```
#
# Vamos a ver como llevamos las tareas
# ```
# curl -i http://localhost:5000/tasks
# ```

# %%
# -*- coding: utf-8 -*-
from flask import Flask, jsonify
# Ahora importamos abort para especificar cuando se ha producido un error
from flask import abort
from flask import make_response
# Ahora vamos a implementar añadir elementos, por lo que necesitamos 
# response, algo que ya vimos con la introducción de datos
# desde un formulario
from flask import request

app = Flask(__name__)

tasks = [
    {
        'id': 1,
        'title': u'Buy groceries',
        'description': u'Milk, Cheese, Pizza, Fruit, Tylenol', 
        'done': False
    },
    {
        'id': 2,
        'title': u'Learn Python',
        'description': u'Need to find a good Python tutorial on the web', 
        'done': False
    }
]

@app.route('/tasks', methods=['GET'])
def get_tasks():
    return jsonify({'tasks': tasks})

@app.route('/tasks/<int:task_id>', methods=['GET'])
def get_task(task_id):
    task = [task for task in tasks if task['id'] == task_id]
    if len(task) == 0:
        abort(404)
    return jsonify({'task': task[0]})

@app.errorhandler(404)
def not_found(error):
    return make_response(jsonify({'error': 'Not found'}), 404)

@app.route('/tasks', methods=['POST'])
def create_task():
    if not request.json or not 'title' in request.json:
        abort(400)
    task = {
        'id': tasks[-1]['id'] + 1,
        'title': request.json['title'],
        'description': request.json.get('description', ""),
        'done': False
    }
    tasks.append(task)
    return jsonify({'task': task}), 201

@app.route('/tasks/<int:task_id>', methods=['PUT'])
def update_task(task_id):
    task = [task for task in tasks if task['id'] == task_id]
    if len(task) == 0:
        abort(404)
    if not request.json:
        abort(400)
    if 'title' in request.json and type(request.json['title']) != unicode:
        abort(400)
    if 'description' in request.json and type(request.json['description']) is not unicode:
        abort(400)
    if 'done' in request.json and type(request.json['done']) is not bool:
        abort(400)
    task[0]['title'] = request.json.get('title', task[0]['title'])
    task[0]['description'] = request.json.get('description', task[0]['description'])
    task[0]['done'] = request.json.get('done', task[0]['done'])
    return jsonify({'task': task[0]})

@app.route('/tasks/<int:task_id>', methods=['DELETE'])
def delete_task(task_id):
    task = [task for task in tasks if task['id'] == task_id]
    if len(task) == 0:
        abort(404)
    tasks.remove(task[0])
    return jsonify({'result': True})

if __name__ == '__main__':
    app.run(debug=True)

# %% [markdown]
# Para actualizar un elemento
# ```
#  curl -i -H "Content-Type: application/json" -X PUT -d '{"done":true}' http://localhost:5000/tasks/1
# ```
#
# Para borrar un elemento
# ```
# curl -i -X DELETE http://localhost:5000/tasks/2
# ```

# %% [markdown]
# ### Ejemplo 04
# Mejorando el sistema. Cuando trabajamos con los datos devueltos por tasks, si queremos consultar una determinada tarea obligamos al usuario a que cree la URI que apunta a dicho recurso, por eso es más conveniente en vez de devolver el identificador, devolver la URI al mismo.

# %%
# -*- coding: utf-8 -*-
from flask import Flask, jsonify
# Ahora importamos abort para especificar cuando se ha producido un error
from flask import abort
from flask import make_response
# Ahora vamos a implementar añadir elementos, por lo que necesitamos 
# response, algo que ya vimos con la introducción de datos
# desde un formulario
from flask import request
# Lo utilizaremos para obtener la url
from flask import url_for


app = Flask(__name__)


tasks = [
    {
        'id': 1,
        'title': u'Buy groceries',
        'description': u'Milk, Cheese, Pizza, Fruit, Tylenol', 
        'done': False
    },
    {
        'id': 2,
        'title': u'Learn Python',
        'description': u'Need to find a good Python tutorial on the web', 
        'done': False
    }
]


def make_public_task(task):
    new_task = {}
    for field in task:
        if field == 'id':
	   #Le indicamos la funciónn que se encarga de devolver una determinada tarea	
            new_task['uri'] = url_for('get_task', task_id=task['id'], _external=True)
        else:
            new_task[field] = task[field]
    return new_task


#Redifinimos la devolucion de las tareas
@app.route('/tasks', methods=['GET'])
def get_tasks():
    return jsonify({'tasks': [make_public_task(task) for task in tasks]})

@app.route('/tasks/<int:task_id>', methods=['GET'])
def get_task(task_id):
    task = [task for task in tasks if task['id'] == task_id]
    if len(task) == 0:
        abort(404)
    return jsonify({'task': task[0]})

@app.errorhandler(404)
def not_found(error):
    return make_response(jsonify({'error': 'Not found'}), 404)

@app.route('/tasks', methods=['POST'])
def create_task():
    if not request.json or not 'title' in request.json:
        abort(400)
    task = {
        'id': tasks[-1]['id'] + 1,
        'title': request.json['title'],
        'description': request.json.get('description', ""),
        'done': False
    }
    tasks.append(task)
    return jsonify({'task': task}), 201

@app.route('/tasks/<int:task_id>', methods=['PUT'])
def update_task(task_id):
    task = [task for task in tasks if task['id'] == task_id]
    if len(task) == 0:
        abort(404)
    if not request.json:
        abort(400)
    if 'title' in request.json and type(request.json['title']) != unicode:
        abort(400)
    if 'description' in request.json and type(request.json['description']) is not unicode:
        abort(400)
    if 'done' in request.json and type(request.json['done']) is not bool:
        abort(400)
    task[0]['title'] = request.json.get('title', task[0]['title'])
    task[0]['description'] = request.json.get('description', task[0]['description'])
    task[0]['done'] = request.json.get('done', task[0]['done'])
    return jsonify({'task': task[0]})

@app.route('/tasks/<int:task_id>', methods=['DELETE'])
def delete_task(task_id):
    task = [task for task in tasks if task['id'] == task_id]
    if len(task) == 0:
        abort(404)
    tasks.remove(task[0])
    return jsonify({'result': True})




if __name__ == '__main__':
    app.run(debug=True)

# %% [markdown]
# ## Ejemplos utilizando restful
# Vamos ahora  trabajar con la libreria flask_restful

# %%
from flask import Flask
from flask_restful import Resource, Api

app = Flask(__name__)
api = Api(app)

class HelloWorld(Resource):
    def get(self):
        return {'hello': 'world'}

api.add_resource(HelloWorld, '/')

if __name__ == '__main__':
    app.run(debug=True)

# %% [markdown]
# Veamos ahora el resultado.
# ```
# $curl -i http://127.0.0.1:5000
# ```

# %%
# -*- coding: utf-8 -*-
from flask import Flask
from flask_restful import reqparse, abort, Api, Resource

app = Flask(__name__)
api = Api(app)

TODOS = {
    'todo1': {'task': 'build an API'},
    'todo2': {'task': '?????'},
    'todo3': {'task': 'profit!'},
}


def abort_if_todo_doesnt_exist(todo_id):
    if todo_id not in TODOS:
        abort(404, message="Todo {} doesn't exist".format(todo_id))

parser = reqparse.RequestParser()
parser.add_argument('task', type=int, help='Task debe ser de tipo entero')


# Todo
# shows a single todo item and lets you delete a todo item
class Todo(Resource):
    def get(self, todo_id):
        abort_if_todo_doesnt_exist(todo_id)
        return TODOS[todo_id]

    def delete(self, todo_id):
        abort_if_todo_doesnt_exist(todo_id)
        del TODOS[todo_id]
        return '', 204

    def put(self, todo_id):
        args = parser.parse_args()
        task = {'task': args['task']}
        TODOS[todo_id] = task
        return task, 201


# TodoList
# shows a list of all todos, and lets you POST to add new tasks
class TodoList(Resource):
    def get(self):
        return TODOS

    def post(self):
        args = parser.parse_args()
        todo_id = int(max(TODOS.keys()).lstrip('todo')) + 1
        todo_id = 'todo%i' % todo_id
        TODOS[todo_id] = {'task': args['task']}
        return TODOS[todo_id], 201

##
## Actually setup the Api resource routing here
##
api.add_resource(TodoList, '/todos')
api.add_resource(Todo, '/todos/<todo_id>')


if __name__ == '__main__':
    app.run(debug=True)

# %% [markdown]
# ### ¿Que pasa en este caso?
# ```
# curl -i http://localhost:5000/todos/todo2 -X PUT -d "task=cadena de datos"
# ```

# %% [markdown]
# ## Enlaces
# http://blog.luisrei.com/articles/flaskrest.html
# http://runnable.com/UuZA5ZA6voMLAAAX/rest-ful-api-example-using-flask-for-python
# http://es.slideshare.net/nicolaiarocci/developing-restful-web-apis-with-python-flask-and-mongodb
# http://www.cs.utexas.edu/~cannata/networking/Class%20Notes/07%20Designing%20a%20RESTful%20API%20with%20Python%20and%20Flask%20-%20miguelgrinberg.pdf
